# %%
# Scheduled Caste Population Growth & Demographic Forecasting System
# AIS Feature Selection Version
# Author: Sagnik Patra

import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

warnings.filterwarnings("ignore")

# =========================
# PATHS
# =========================

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\Percentage_of_Scheduled_Caste_Population_to_Total_Population.csv"

OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "ais_"

# =========================
# LOAD DATA
# =========================

df = pd.read_csv(DATASET_PATH)
df.columns = df.columns.str.strip()

district_col = "District"

# =========================
# FEATURE ENGINEERING
# =========================

df["Rural_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2001_Rural"]
)

df["Urban_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Urban"]
    - df["Percentage of Scheduled Caste Population _2001_Urban"]
)

df["Total_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    - df["Percentage of Scheduled Caste Population _2001_Total"]
)

df["Rural_Urban_Gap_2011"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2011_Urban"]
)

df["Estimated_2021_Total_SC_Percentage"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    + df["Total_Growth"]
)

feature_cols = [
    "Percentage of Scheduled Caste Population _2001_Rural",
    "Percentage of Scheduled Caste Population _2001_Urban",
    "Percentage of Scheduled Caste Population _2001_Total",
    "Percentage of Scheduled Caste Population _2011_Rural",
    "Percentage of Scheduled Caste Population _2011_Urban",
    "Percentage of Scheduled Caste Population _2011_Total",
    "Rural_Growth",
    "Urban_Growth",
    "Total_Growth",
    "Rural_Urban_Gap_2011",
]

target_col = "Estimated_2021_Total_SC_Percentage"

X = df[feature_cols]
y = df[target_col]

# =========================
# TRAIN TEST SPLIT
# =========================

X_train, X_test, y_train, y_test, district_train, district_test = train_test_split(
    X,
    y,
    df[district_col],
    test_size=0.2,
    random_state=42
)

# =========================
# SCALING
# =========================

scaler = StandardScaler()
X_train_scaled_full = scaler.fit_transform(X_train)
X_test_scaled_full = scaler.transform(X_test)

scaler_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)

# =========================
# AIS FEATURE SELECTION
# =========================

def fitness_function(mask, X_train_data, X_test_data, y_train_data, y_test_data):
    if np.sum(mask) == 0:
        return -9999

    selected_train = X_train_data[:, mask == 1]
    selected_test = X_test_data[:, mask == 1]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(selected_train, y_train_data)

    preds = model.predict(selected_test)
    r2 = r2_score(y_test_data, preds)

    penalty = np.sum(mask) / len(mask) * 0.01

    return r2 - penalty


def ais_feature_selection(
    X_train_data,
    X_test_data,
    y_train_data,
    y_test_data,
    num_features,
    population_size=20,
    generations=30,
    clone_factor=5,
    mutation_rate=0.2
):
    population = np.random.randint(0, 2, size=(population_size, num_features))

    best_antibody = None
    best_fitness = -9999
    fitness_history = []

    for generation in range(generations):
        fitness_scores = np.array([
            fitness_function(individual, X_train_data, X_test_data, y_train_data, y_test_data)
            for individual in population
        ])

        sorted_indices = np.argsort(fitness_scores)[::-1]
        population = population[sorted_indices]
        fitness_scores = fitness_scores[sorted_indices]

        if fitness_scores[0] > best_fitness:
            best_fitness = fitness_scores[0]
            best_antibody = population[0].copy()

        fitness_history.append(best_fitness)

        elite_count = max(2, population_size // 4)
        elites = population[:elite_count]

        clones = []

        for elite in elites:
            for _ in range(clone_factor):
                clone = elite.copy()

                for i in range(num_features):
                    if np.random.rand() < mutation_rate:
                        clone[i] = 1 - clone[i]

                if np.sum(clone) == 0:
                    clone[np.random.randint(0, num_features)] = 1

                clones.append(clone)

        random_new = np.random.randint(
            0,
            2,
            size=(population_size - len(elites), num_features)
        )

        population = np.vstack([
            elites,
            np.array(clones)[:population_size - elite_count]
        ])

        if population.shape[0] < population_size:
            population = np.vstack([
                population,
                random_new[:population_size - population.shape[0]]
            ])

        print(f"Generation {generation + 1}/{generations} | Best Fitness: {best_fitness:.4f}")

    return best_antibody, best_fitness, fitness_history


selected_mask, best_ais_fitness, ais_history = ais_feature_selection(
    X_train_scaled_full,
    X_test_scaled_full,
    y_train,
    y_test,
    num_features=X_train_scaled_full.shape[1]
)

selected_features = [
    feature for feature, selected in zip(feature_cols, selected_mask)
    if selected == 1
]

X_train_scaled = X_train_scaled_full[:, selected_mask == 1]
X_test_scaled = X_test_scaled_full[:, selected_mask == 1]

# =========================
# TRAIN MODELS ON AIS FEATURES
# =========================

models = {
    "AIS_RandomForest": RandomForestRegressor(n_estimators=200, random_state=42),
    "AIS_GradientBoosting": GradientBoostingRegressor(
        n_estimators=200,
        learning_rate=0.05,
        random_state=42
    )
}

results = []
all_predictions = {}

best_model = None
best_model_name = None
best_r2 = -999

for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)

    all_predictions[name] = preds

    mae = mean_absolute_error(y_test, preds)
    mse = mean_squared_error(y_test, preds)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, preds)

    results.append({
        "Model": name,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2_Score": r2,
        "Accuracy_Percentage": r2 * 100
    })

    model_path = os.path.join(OUTPUT_DIR, PREFIX + name.lower() + "_model.pkl")

    with open(model_path, "wb") as f:
        pickle.dump(model, f)

    if r2 > best_r2:
        best_r2 = r2
        best_model = model
        best_model_name = name

# =========================
# DEEP LEARNING MODEL
# =========================

dl_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dense(1)
])

dl_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = dl_model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,
    epochs=300,
    batch_size=8,
    callbacks=[early_stop],
    verbose=1
)

dl_preds = dl_model.predict(X_test_scaled).flatten()

all_predictions["AIS_DeepNeuralNetwork"] = dl_preds

dl_mae = mean_absolute_error(y_test, dl_preds)
dl_mse = mean_squared_error(y_test, dl_preds)
dl_rmse = np.sqrt(dl_mse)
dl_r2 = r2_score(y_test, dl_preds)

results.append({
    "Model": "AIS_DeepNeuralNetwork",
    "MAE": dl_mae,
    "MSE": dl_mse,
    "RMSE": dl_rmse,
    "R2_Score": dl_r2,
    "Accuracy_Percentage": dl_r2 * 100
})

h5_path = os.path.join(OUTPUT_DIR, PREFIX + "deep_learning_model.h5")
dl_model.save(h5_path)

if dl_r2 > best_r2:
    best_r2 = dl_r2
    best_model_name = "AIS_DeepNeuralNetwork"

# =========================
# SAVE BEST MODEL
# =========================

best_model_path = os.path.join(OUTPUT_DIR, PREFIX + "best_model.pkl")

if best_model is not None:
    with open(best_model_path, "wb") as f:
        pickle.dump(best_model, f)

# =========================
# SAVE FEATURE MASK
# =========================

feature_selection_data = {
    "selected_mask": selected_mask.tolist(),
    "selected_features": selected_features,
    "best_ais_fitness": float(best_ais_fitness),
    "ais_history": [float(x) for x in ais_history]
}

feature_selection_path = os.path.join(OUTPUT_DIR, PREFIX + "feature_selection.json")

with open(feature_selection_path, "w") as f:
    json.dump(feature_selection_data, f, indent=4)

# =========================
# CSV FILES
# =========================

results_df = pd.DataFrame(results)

results_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "results.csv")
results_df.to_csv(results_csv_path, index=False)

prediction_df = pd.DataFrame({
    "District": district_test.values,
    "Actual_2021_Estimated_SC_Percentage": y_test.values
})

for model_name, preds in all_predictions.items():
    prediction_df[f"{model_name}_Prediction"] = preds

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "predictions.csv")
prediction_df.to_csv(prediction_csv_path, index=False)

# =========================
# JSON FILE
# =========================

json_data = {
    "project_name": "Scheduled Caste Population Growth & Demographic Forecasting System",
    "author": "Sagnik Patra",
    "algorithm": "Artificial Immune System Feature Selection",
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": target_col,
    "all_features": feature_cols,
    "selected_features": selected_features,
    "best_model": best_model_name,
    "best_r2_score": float(best_r2),
    "best_ais_fitness": float(best_ais_fitness),
    "model_results": results_df.to_dict(orient="records")
}

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

with open(json_path, "w") as f:
    json.dump(json_data, f, indent=4)

# =========================
# YAML CONFIG
# =========================

yaml_config = {
    "project": {
        "name": "Scheduled Caste Population Growth & Demographic Forecasting System",
        "author": "Sagnik Patra",
        "prefix": PREFIX,
        "algorithm": "AIS"
    },
    "paths": {
        "dataset_path": DATASET_PATH,
        "output_directory": OUTPUT_DIR,
        "h5_model": h5_path,
        "best_model_pkl": best_model_path,
        "scaler_pkl": scaler_path,
        "results_csv": results_csv_path,
        "predictions_csv": prediction_csv_path,
        "json_results": json_path,
        "feature_selection_json": feature_selection_path
    },
    "training": {
        "test_size": 0.2,
        "random_state": 42,
        "target_column": target_col,
        "all_features": feature_cols,
        "selected_features": selected_features
    },
    "ais_parameters": {
        "population_size": 20,
        "generations": 30,
        "clone_factor": 5,
        "mutation_rate": 0.2
    },
    "best_model": best_model_name
}

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

with open(yaml_path, "w") as f:
    yaml.dump(yaml_config, f, default_flow_style=False)

# =========================
# GRAPHS
# =========================

plt.figure(figsize=(10, 6))
plt.bar(results_df["Model"], results_df["Accuracy_Percentage"])
plt.xlabel("Models")
plt.ylabel("Accuracy Percentage")
plt.title("AIS Model Accuracy Graph")
plt.xticks(rotation=30)
plt.tight_layout()
accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")
plt.savefig(accuracy_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["MAE"], marker="o", label="MAE")
plt.plot(results_df["Model"], results_df["RMSE"], marker="o", label="RMSE")
plt.xlabel("Models")
plt.ylabel("Error Value")
plt.title("AIS Comparison Graph")
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()
comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")
plt.savefig(comparison_graph_path)
plt.show()

corr = df[selected_features + [target_col]].corr()

plt.figure(figsize=(12, 8))
plt.imshow(corr, interpolation="nearest")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("AIS Selected Feature Heatmap")
plt.tight_layout()
heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")
plt.savefig(heatmap_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["R2_Score"], marker="o")
plt.xlabel("Models")
plt.ylabel("R2 Score")
plt.title("AIS Result Graph")
plt.xticks(rotation=30)
plt.tight_layout()
result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")
plt.savefig(result_graph_path)
plt.show()

best_prediction_col = f"{best_model_name}_Prediction"

plt.figure(figsize=(12, 6))
plt.plot(
    prediction_df["District"],
    prediction_df["Actual_2021_Estimated_SC_Percentage"],
    marker="o",
    label="Actual"
)
plt.plot(
    prediction_df["District"],
    prediction_df[best_prediction_col],
    marker="o",
    label="Predicted"
)
plt.xlabel("District")
plt.ylabel("SC Population Percentage")
plt.title(f"AIS Prediction Graph - {best_model_name}")
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")
plt.savefig(prediction_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(ais_history, marker="o")
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("AIS Optimization Progress Graph")
plt.tight_layout()
optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")
plt.savefig(optimization_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("AIS Deep Learning Loss Graph")
plt.legend()
plt.tight_layout()
dl_loss_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "dl_loss_graph.png")
plt.savefig(dl_loss_graph_path)
plt.show()

# =========================
# FINAL OUTPUT
# =========================

print("\nAIS execution completed successfully!")

print("\nSelected Features:")
for feature in selected_features:
    print("-", feature)

print("\nSaved Files:")
print(results_csv_path)
print(prediction_csv_path)
print(h5_path)
print(best_model_path)
print(scaler_path)
print(json_path)
print(yaml_path)
print(feature_selection_path)

print("\nSaved Graphs:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(dl_loss_graph_path)

print("\nModel Results:")
print(results_df)
# Out:
# Generation 1/30 | Best Fitness: 0.9687
# Generation 2/30 | Best Fitness: 0.9783
# Generation 3/30 | Best Fitness: 0.9817
# Generation 4/30 | Best Fitness: 0.9817
# Generation 5/30 | Best Fitness: 0.9832
# Generation 6/30 | Best Fitness: 0.9847
# Generation 7/30 | Best Fitness: 0.9847
# Generation 8/30 | Best Fitness: 0.9847
# Generation 9/30 | Best Fitness: 0.9847
# Generation 10/30 | Best Fitness: 0.9847
# Generation 11/30 | Best Fitness: 0.9847
# Generation 12/30 | Best Fitness: 0.9847
# Generation 13/30 | Best Fitness: 0.9847
# Generation 14/30 | Best Fitness: 0.9847
# Generation 15/30 | Best Fitness: 0.9847
# Generation 16/30 | Best Fitness: 0.9847
# Generation 17/30 | Best Fitness: 0.9847
# Generation 18/30 | Best Fitness: 0.9847
# Generation 19/30 | Best Fitness: 0.9847
# Generation 20/30 | Best Fitness: 0.9847
# Generation 21/30 | Best Fitness: 0.9847
# Generation 22/30 | Best Fitness: 0.9847
# Generation 23/30 | Best Fitness: 0.9847
# Generation 24/30 | Best Fitness: 0.9847
# Generation 25/30 | Best Fitness: 0.9847
# Generation 26/30 | Best Fitness: 0.9847
# Generation 27/30 | Best Fitness: 0.9847
# Generation 28/30 | Best Fitness: 0.9847
# Generation 29/30 | Best Fitness: 0.9847
# Generation 30/30 | Best Fitness: 0.9847
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 508.7964 - mae: 20.2984 - val_loss: 505.2260 - val_mae: 20.4247
# Epoch 2/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 499.0389 - mae: 20.1011 - val_loss: 492.0104 - val_mae: 20.1534
# Epoch 3/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 481.5603 - mae: 19.7551 - val_loss: 469.2870 - val_mae: 19.6666
# Epoch 4/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 452.1995 - mae: 19.1357 - val_loss: 430.3505 - val_mae: 18.8013
# Epoch 5/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 407.7980 - mae: 18.0543 - val_loss: 362.5362 - val_mae: 17.1811
# Epoch 6/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 326.8162 - mae: 15.9875 - val_loss: 258.7376 - val_mae: 14.4729
# Epoch 7/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 218.7330 - mae: 12.9739 - val_loss: 137.7234 - val_mae: 10.6702
# Epoch 8/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 112.4194 - mae: 9.0847 - val_loss: 40.5582 - val_mae: 5.8107
# Epoch 9/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.3428 - mae: 5.3709 - val_loss: 15.5983 - val_mae: 3.2672
# Epoch 10/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.5252 - mae: 4.4904 - val_loss: 14.0510 - val_mae: 3.1318
# Epoch 11/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35
# Epoch 53/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8406 - mae: 1.5857 - val_loss: 0.1289 - val_mae: 0.3067
# Epoch 54/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1734 - mae: 1.6418 - val_loss: 0.8191 - val_mae: 0.7039
# Epoch 55/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4669 - mae: 1.6488 - val_loss: 0.6758 - val_mae: 0.7809
# Epoch 56/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9223 - mae: 1.5202 - val_loss: 0.2288 - val_mae: 0.3992
# Epoch 57/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4141 - mae: 1.3509 - val_loss: 0.2243 - val_mae: 0.3829
# Epoch 58/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5972 - mae: 1.3491 - val_loss: 0.1404 - val_mae: 0.2923
# Epoch 59/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6998 - mae: 1.7186 - val_loss: 0.1852 - val_mae: 0.3081
# Epoch 60/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5416 - mae: 1.4418 - val_loss: 0.4152 - val_mae: 0.5647
# Epoch 61/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3583 - mae: 1.3237 - val_loss: 0.1348 - val_mae: 0.2975
# Epoch 62/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6195 - mae: 1.5544 - val_loss: 0.0882 - val_mae: 0.2047
# Epoch 63/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8273 - mae: 1.4121 - val_loss: 0.4472 - val_mae: 0.5717
# Epoch 64/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0189 - mae: 1.5440 - val_loss: 0.1602 - val_mae: 0.3311
# Epoch 65/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6434 - mae: 1.3407 - val_loss: 0.1220 - val_mae: 0.2450
# Epoch 66/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9267 - mae: 1.4932 - val_loss: 0.1205 - val_mae: 0.2444
# Epoch 67/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0509 - mae: 1.3686 - val_loss: 0.2760 - val_mae: 0.4112
# Epoch 68/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0550 - mae: 1.5603 - val_loss: 0.1641 - val_mae: 0.2547
# Epoch 69/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3209 - mae: 1.2969 - val_loss: 0.2610 - val_mae: 0.3767
# Epoch 70/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4990 - mae: 1.2039 - val_loss: 0.2227 - val_mae: 0.3189
# Epoch 71/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7083 - mae: 1.4417 - val_loss: 0.2116 - val_mae: 0.2803
# Epoch 72/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8547 - mae: 1.2914 - val_loss: 0.2515 - val_mae: 0.3066
# Epoch 73/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0460 - mae: 1.4286 - val_loss: 0.2703 - val_mae: 0.3717
# Epoch 74/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4091 - mae: 1.3561 - val_loss: 0.3463 - val_mae: 0.4587
# Epoch 75/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4681 - mae: 1.2330 - val_loss: 0.2952 - val_mae: 0.4013
# Epoch 76/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7006 - mae: 1.4055 - val_loss: 0.0914 - val_mae: 0.2279
# Epoch 77/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3716 - mae: 1.3832 - val_loss: 0.0945 - val_mae: 0.2239
# Epoch 78/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5259 - mae: 1.4142 - val_loss: 0.1737 - val_mae: 0.3266
# Epoch 79/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2250 - mae: 1.4147 - val_loss: 0.4626 - val_mae: 0.5088
# Epoch 80/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3023 - mae: 1.3337 - val_loss: 0.2202 - val_mae: 0.3046
# Epoch 81/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2839 - mae: 1.4016 - val_loss: 0.1804 - val_mae: 0.3563
# Epoch 82/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4016 - mae: 1.4009 - val_loss: 0.1332 - val_mae: 0.2262
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# AIS execution completed successfully!
#
# Selected Features:
# - Percentage of Scheduled Caste Population _2011_Total
# - Total_Growth
#
# Saved Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_results.csv
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_predictions.csv
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_deep_learning_model.h5
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_best_model.pkl
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_scaler.pkl
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_results.json
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_config.yaml
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_feature_selection.json
#
# Saved Graphs:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_heatmap.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_result_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ais_dl_loss_graph.png
#
# Model Results:
#                    Model       MAE       MSE      RMSE  R2_Score  \
# 0       AIS_RandomForest  0.553333  0.972943  0.986379  0.986569
# 1   AIS_GradientBoosting  0.628537  1.319978  1.148903  0.981779
# 2  AIS_DeepNeuralNetwork  0.182059  0.110331  0.332162  0.998477
#
#    Accuracy_Percentage
# 0            98.656914
# 1            98.177856
# 2            99.847695
