# %%
# Scheduled Caste Population Growth & Demographic Forecasting System
# BA Feature Selection Version
# Author: Sagnik Patra

import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

warnings.filterwarnings("ignore")

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\Percentage_of_Scheduled_Caste_Population_to_Total_Population.csv"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "ba_"

# =========================
# LOAD DATA
# =========================

df = pd.read_csv(DATASET_PATH)
df.columns = df.columns.str.strip()

district_col = "District"

# =========================
# FEATURE ENGINEERING
# =========================

df["Rural_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2001_Rural"]
)

df["Urban_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Urban"]
    - df["Percentage of Scheduled Caste Population _2001_Urban"]
)

df["Total_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    - df["Percentage of Scheduled Caste Population _2001_Total"]
)

df["Rural_Urban_Gap_2011"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2011_Urban"]
)

df["Estimated_2021_Total_SC_Percentage"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    + df["Total_Growth"]
)

feature_cols = [
    "Percentage of Scheduled Caste Population _2001_Rural",
    "Percentage of Scheduled Caste Population _2001_Urban",
    "Percentage of Scheduled Caste Population _2001_Total",
    "Percentage of Scheduled Caste Population _2011_Rural",
    "Percentage of Scheduled Caste Population _2011_Urban",
    "Percentage of Scheduled Caste Population _2011_Total",
    "Rural_Growth",
    "Urban_Growth",
    "Total_Growth",
    "Rural_Urban_Gap_2011",
]

target_col = "Estimated_2021_Total_SC_Percentage"

X = df[feature_cols]
y = df[target_col]

# =========================
# TRAIN TEST SPLIT
# =========================

X_train, X_test, y_train, y_test, district_train, district_test = train_test_split(
    X,
    y,
    df[district_col],
    test_size=0.2,
    random_state=42
)

# =========================
# SCALING
# =========================

scaler = StandardScaler()
X_train_scaled_full = scaler.fit_transform(X_train)
X_test_scaled_full = scaler.transform(X_test)

scaler_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")

with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)

# =========================
# BAT ALGORITHM FEATURE SELECTION
# =========================

def fitness_function(mask, X_train_data, X_test_data, y_train_data, y_test_data):
    if np.sum(mask) == 0:
        return -9999

    selected_train = X_train_data[:, mask == 1]
    selected_test = X_test_data[:, mask == 1]

    model = RandomForestRegressor(
        n_estimators=100,
        random_state=42
    )

    model.fit(selected_train, y_train_data)
    preds = model.predict(selected_test)

    r2 = r2_score(y_test_data, preds)
    penalty = 0.01 * (np.sum(mask) / len(mask))

    return r2 - penalty


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ba_feature_selection(
    X_train_data,
    X_test_data,
    y_train_data,
    y_test_data,
    num_features,
    num_bats=25,
    iterations=30,
    freq_min=0,
    freq_max=2,
    loudness=0.5,
    pulse_rate=0.5
):
    positions = np.random.randint(0, 2, size=(num_bats, num_features))
    velocities = np.random.uniform(-1, 1, size=(num_bats, num_features))
    frequencies = np.zeros(num_bats)

    for bat in positions:
        if np.sum(bat) == 0:
            bat[np.random.randint(0, num_features)] = 1

    fitness_scores = np.array([
        fitness_function(
            bat,
            X_train_data,
            X_test_data,
            y_train_data,
            y_test_data
        )
        for bat in positions
    ])

    best_index = np.argmax(fitness_scores)
    best_position = positions[best_index].copy()
    best_fitness = fitness_scores[best_index]

    fitness_history = []

    for iteration in range(iterations):
        for i in range(num_bats):
            frequencies[i] = freq_min + (freq_max - freq_min) * np.random.rand()

            velocities[i] = (
                velocities[i]
                + (positions[i] - best_position) * frequencies[i]
            )

            probabilities = sigmoid(velocities[i])
            new_position = (
                np.random.rand(num_features) < probabilities
            ).astype(int)

            if np.random.rand() > pulse_rate:
                random_walk = best_position.copy()
                mutation_index = np.random.randint(0, num_features)
                random_walk[mutation_index] = 1 - random_walk[mutation_index]
                new_position = random_walk

            if np.sum(new_position) == 0:
                new_position[np.random.randint(0, num_features)] = 1

            new_fitness = fitness_function(
                new_position,
                X_train_data,
                X_test_data,
                y_train_data,
                y_test_data
            )

            if new_fitness > fitness_scores[i] and np.random.rand() < loudness:
                positions[i] = new_position
                fitness_scores[i] = new_fitness

            if fitness_scores[i] > best_fitness:
                best_fitness = fitness_scores[i]
                best_position = positions[i].copy()

        fitness_history.append(best_fitness)

        print(
            f"Iteration {iteration + 1}/{iterations} | "
            f"Best BA Fitness: {best_fitness:.4f}"
        )

    return best_position, best_fitness, fitness_history


selected_mask, best_ba_fitness, ba_history = ba_feature_selection(
    X_train_scaled_full,
    X_test_scaled_full,
    y_train,
    y_test,
    num_features=X_train_scaled_full.shape[1]
)

selected_features = [
    feature for feature, selected in zip(feature_cols, selected_mask)
    if selected == 1
]

X_train_scaled = X_train_scaled_full[:, selected_mask == 1]
X_test_scaled = X_test_scaled_full[:, selected_mask == 1]

# =========================
# TRAIN MODELS ON BA FEATURES
# =========================

models = {
    "BA_RandomForest": RandomForestRegressor(
        n_estimators=200,
        random_state=42
    ),
    "BA_GradientBoosting": GradientBoostingRegressor(
        n_estimators=200,
        learning_rate=0.05,
        random_state=42
    )
}

results = []
all_predictions = {}

best_model = None
best_model_name = None
best_r2 = -999

for name, model in models.items():
    model.fit(X_train_scaled, y_train)

    preds = model.predict(X_test_scaled)
    all_predictions[name] = preds

    mae = mean_absolute_error(y_test, preds)
    mse = mean_squared_error(y_test, preds)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, preds)

    results.append({
        "Model": name,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2_Score": r2,
        "Accuracy_Percentage": r2 * 100
    })

    model_path = os.path.join(
        OUTPUT_DIR,
        PREFIX + name.lower() + "_model.pkl"
    )

    with open(model_path, "wb") as f:
        pickle.dump(model, f)

    if r2 > best_r2:
        best_r2 = r2
        best_model = model
        best_model_name = name

# =========================
# DEEP LEARNING MODEL
# =========================

dl_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dense(1)
])

dl_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = dl_model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,
    epochs=300,
    batch_size=8,
    callbacks=[early_stop],
    verbose=1
)

dl_preds = dl_model.predict(X_test_scaled).flatten()

all_predictions["BA_DeepNeuralNetwork"] = dl_preds

dl_mae = mean_absolute_error(y_test, dl_preds)
dl_mse = mean_squared_error(y_test, dl_preds)
dl_rmse = np.sqrt(dl_mse)
dl_r2 = r2_score(y_test, dl_preds)

results.append({
    "Model": "BA_DeepNeuralNetwork",
    "MAE": dl_mae,
    "MSE": dl_mse,
    "RMSE": dl_rmse,
    "R2_Score": dl_r2,
    "Accuracy_Percentage": dl_r2 * 100
})

h5_path = os.path.join(OUTPUT_DIR, PREFIX + "deep_learning_model.h5")
dl_model.save(h5_path)

if dl_r2 > best_r2:
    best_r2 = dl_r2
    best_model_name = "BA_DeepNeuralNetwork"

# =========================
# SAVE BEST MODEL
# =========================

best_model_path = os.path.join(OUTPUT_DIR, PREFIX + "best_model.pkl")

if best_model is not None:
    with open(best_model_path, "wb") as f:
        pickle.dump(best_model, f)

# =========================
# SAVE FEATURE SELECTION JSON
# =========================

feature_selection_data = {
    "algorithm": "Bat Algorithm",
    "selected_mask": selected_mask.tolist(),
    "selected_features": selected_features,
    "best_ba_fitness": float(best_ba_fitness),
    "ba_history": [float(x) for x in ba_history]
}

feature_selection_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "feature_selection.json"
)

with open(feature_selection_path, "w") as f:
    json.dump(feature_selection_data, f, indent=4)

# =========================
# CSV FILES
# =========================

results_df = pd.DataFrame(results)

results_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "results.csv")
results_df.to_csv(results_csv_path, index=False)

prediction_df = pd.DataFrame({
    "District": district_test.values,
    "Actual_2021_Estimated_SC_Percentage": y_test.values
})

for model_name, preds in all_predictions.items():
    prediction_df[f"{model_name}_Prediction"] = preds

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "predictions.csv")
prediction_df.to_csv(prediction_csv_path, index=False)

# =========================
# JSON RESULT FILE
# =========================

json_data = {
    "project_name": "Scheduled Caste Population Growth & Demographic Forecasting System",
    "author": "Sagnik Patra",
    "algorithm": "Bat Algorithm Feature Selection",
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": target_col,
    "all_features": feature_cols,
    "selected_features": selected_features,
    "best_model": best_model_name,
    "best_r2_score": float(best_r2),
    "best_ba_fitness": float(best_ba_fitness),
    "model_results": results_df.to_dict(orient="records")
}

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

with open(json_path, "w") as f:
    json.dump(json_data, f, indent=4)

# =========================
# YAML CONFIG FILE
# =========================

yaml_config = {
    "project": {
        "name": "Scheduled Caste Population Growth & Demographic Forecasting System",
        "author": "Sagnik Patra",
        "prefix": PREFIX,
        "algorithm": "BA"
    },
    "paths": {
        "dataset_path": DATASET_PATH,
        "output_directory": OUTPUT_DIR,
        "h5_model": h5_path,
        "best_model_pkl": best_model_path,
        "scaler_pkl": scaler_path,
        "results_csv": results_csv_path,
        "predictions_csv": prediction_csv_path,
        "json_results": json_path,
        "feature_selection_json": feature_selection_path
    },
    "training": {
        "test_size": 0.2,
        "random_state": 42,
        "target_column": target_col,
        "all_features": feature_cols,
        "selected_features": selected_features
    },
    "ba_parameters": {
        "num_bats": 25,
        "iterations": 30,
        "freq_min": 0,
        "freq_max": 2,
        "loudness": 0.5,
        "pulse_rate": 0.5
    },
    "best_model": best_model_name
}

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

with open(yaml_path, "w") as f:
    yaml.dump(yaml_config, f, default_flow_style=False)

# =========================
# GRAPHS
# =========================

plt.figure(figsize=(10, 6))
plt.bar(results_df["Model"], results_df["Accuracy_Percentage"])
plt.xlabel("Models")
plt.ylabel("Accuracy Percentage")
plt.title("BA Model Accuracy Graph")
plt.xticks(rotation=30)
plt.tight_layout()

accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")
plt.savefig(accuracy_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["MAE"], marker="o", label="MAE")
plt.plot(results_df["Model"], results_df["RMSE"], marker="o", label="RMSE")
plt.xlabel("Models")
plt.ylabel("Error Value")
plt.title("BA Comparison Graph")
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()

comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")
plt.savefig(comparison_graph_path)
plt.show()

corr = df[selected_features + [target_col]].corr()

plt.figure(figsize=(12, 8))
plt.imshow(corr, interpolation="nearest")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("BA Selected Feature Heatmap")
plt.tight_layout()

heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")
plt.savefig(heatmap_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["R2_Score"], marker="o")
plt.xlabel("Models")
plt.ylabel("R2 Score")
plt.title("BA Result Graph")
plt.xticks(rotation=30)
plt.tight_layout()

result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")
plt.savefig(result_graph_path)
plt.show()

best_prediction_col = f"{best_model_name}_Prediction"

plt.figure(figsize=(12, 6))
plt.plot(
    prediction_df["District"],
    prediction_df["Actual_2021_Estimated_SC_Percentage"],
    marker="o",
    label="Actual"
)

plt.plot(
    prediction_df["District"],
    prediction_df[best_prediction_col],
    marker="o",
    label="Predicted"
)

plt.xlabel("District")
plt.ylabel("SC Population Percentage")
plt.title(f"BA Prediction Graph - {best_model_name}")
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()

prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")
plt.savefig(prediction_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(ba_history, marker="o")
plt.xlabel("Iteration")
plt.ylabel("Best Fitness")
plt.title("BA Optimization Progress Graph")
plt.tight_layout()

optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")
plt.savefig(optimization_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("BA Deep Learning Loss Graph")
plt.legend()
plt.tight_layout()

dl_loss_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "dl_loss_graph.png")
plt.savefig(dl_loss_graph_path)
plt.show()

# =========================
# FINAL OUTPUT
# =========================

print("\nBA execution completed successfully!")

print("\nSelected Features:")
for feature in selected_features:
    print("-", feature)

print("\nSaved CSV Files:")
print(results_csv_path)
print(prediction_csv_path)

print("\nSaved Model Files:")
print(h5_path)
print(best_model_path)
print(scaler_path)

print("\nSaved Config Files:")
print(json_path)
print(yaml_path)
print(feature_selection_path)

print("\nSaved Graphs:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(dl_loss_graph_path)

print("\nModel Results:")
print(results_df)
# Out:
# Iteration 1/30 | Best BA Fitness: 0.9820
# Iteration 2/30 | Best BA Fitness: 0.9825
# Iteration 3/30 | Best BA Fitness: 0.9847
# Iteration 4/30 | Best BA Fitness: 0.9847
# Iteration 5/30 | Best BA Fitness: 0.9847
# Iteration 6/30 | Best BA Fitness: 0.9847
# Iteration 7/30 | Best BA Fitness: 0.9847
# Iteration 8/30 | Best BA Fitness: 0.9847
# Iteration 9/30 | Best BA Fitness: 0.9847
# Iteration 10/30 | Best BA Fitness: 0.9847
# Iteration 11/30 | Best BA Fitness: 0.9847
# Iteration 12/30 | Best BA Fitness: 0.9847
# Iteration 13/30 | Best BA Fitness: 0.9847
# Iteration 14/30 | Best BA Fitness: 0.9847
# Iteration 15/30 | Best BA Fitness: 0.9847
# Epoch 31/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7922 - mae: 1.4894 - val_loss: 0.2488 - val_mae: 0.3852
# Epoch 32/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1693 - mae: 1.4838 - val_loss: 0.2637 - val_mae: 0.4715
# Epoch 33/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2556 - mae: 1.5210 - val_loss: 0.3203 - val_mae: 0.3596
# Epoch 34/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3545 - mae: 1.5688 - val_loss: 0.2919 - val_mae: 0.4573
# Epoch 35/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9075 - mae: 1.7521 - val_loss: 0.1570 - val_mae: 0.2860
# Epoch 36/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7717 - mae: 1.7128 - val_loss: 0.3555 - val_mae: 0.4757
# Epoch 37/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3311 - mae: 1.4899 - val_loss: 0.1972 - val_mae: 0.2793
# Epoch 38/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8258 - mae: 1.5905 - val_loss: 0.5603 - val_mae: 0.6169
# Epoch 39/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2733 - mae: 1.4532 - val_loss: 0.1925 - val_mae: 0.2933
# Epoch 40/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9328 - mae: 1.5308 - val_loss: 0.3163 - val_mae: 0.3483
# Epoch 41/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3708 - mae: 1.5420 - val_loss: 0.1981 - val_mae: 0.3816
# Epoch 42/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4529 - mae: 1.5399 - val_loss: 0.1488 - val_mae: 0.2623
# Epoch 43/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5077 - mae: 1.5348 - val_loss: 0.2337 - val_mae: 0.3274
# Epoch 44/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0919 - mae: 1.5370 - val_loss: 0.2707 - val_mae: 0.3740
# Epoch 45/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2371 - mae: 1.3624 - val_loss: 0.5954 - val_mae: 0.6273
# Epoch 46/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9280 - mae: 1.3500 - val_loss: 0.2158 - val_mae: 0.3209
# Epoch 47/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1550 - mae: 1.3155 - val_loss: 0.1980 - val_mae: 0.2969
# Epoch 48/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8516 - mae: 1.3544 - val_loss: 0.2457 - val_mae: 0.3131
# Epoch 49/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1524 - mae: 1.3259 - val_loss: 0.2670 - val_mae: 0.3043
# Epoch 50/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8911 - mae: 1.5305 - val_loss: 0.2141 - val_mae: 0.2885
# Epoch 51/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1145 - mae: 1.3305 - val_loss: 0.2940 - val_mae: 0.3681
# Epoch 52/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2104 - mae: 1.3788 - val_loss: 0.3469 - val_mae: 0.5056
# Epoch 53/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8095 - mae: 1.3707 - val_loss: 0.5364 - val_mae: 0.5639
# Epoch 54/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0531 - mae: 1.3466 - val_loss: 0.2664 - val_mae: 0.2730
# Epoch 55/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8032 - mae: 1.3965 - val_loss: 0.4797 - val_mae: 0.4670
# Epoch 56/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3465 - mae: 1.3058 - val_loss: 0.3925 - val_mae: 0.5544
# Epoch 57/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7423 - mae: 1.3921 - val_loss: 0.8432 - val_mae: 0.6942
# Epoch 58/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2506 - mae: 1.3040 - val_loss: 0.4989 - val_mae: 0.5407
# Epoch 59/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6152 - mae: 1.5301 - val_loss: 0.5808 - val_mae: 0.4382
# Epoch 60/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0365 - mae: 1.1825 - val_loss: 0.4524 - val_mae: 0.3753
# Epoch 61/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2891 - mae: 1.2638 - val_loss: 0.4034 - val_mae: 0.2954
# Epoch 62/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4597 - mae: 1.3796 - val_loss: 2.3099 - val_mae: 1.2640
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# BA execution completed successfully!
#
# Selected Features:
# - Percentage of Scheduled Caste Population _2011_Total
# - Total_Growth
#
# Saved CSV Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_results.csv
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_predictions.csv
#
# Saved Model Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_deep_learning_model.h5
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_best_model.pkl
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_scaler.pkl
#
# Saved Config Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_results.json
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_config.yaml
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_feature_selection.json
#
# Saved Graphs:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_heatmap.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_result_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\ba_dl_loss_graph.png
#
# Model Results:
#                   Model       MAE       MSE      RMSE  R2_Score  \
# 0       BA_RandomForest  0.553333  0.972943  0.986379  0.986569
# 1   BA_GradientBoosting  0.628537  1.319978  1.148903  0.981779
# 2  BA_DeepNeuralNetwork  0.262256  0.294161  0.542366  0.995939
#
#    Accuracy_Percentage
# 0            98.656914
# 1            98.177856
# 2            99.593930
