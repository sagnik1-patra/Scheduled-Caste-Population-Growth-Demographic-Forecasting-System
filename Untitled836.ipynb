# %%
# Scheduled Caste Population Growth & Demographic Forecasting System
# HSA Feature Selection Version
# Author: Sagnik Patra

import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

warnings.filterwarnings("ignore")

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\Percentage_of_Scheduled_Caste_Population_to_Total_Population.csv"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "hsa_"

df = pd.read_csv(DATASET_PATH)
df.columns = df.columns.str.strip()

district_col = "District"

df["Rural_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2001_Rural"]
)

df["Urban_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Urban"]
    - df["Percentage of Scheduled Caste Population _2001_Urban"]
)

df["Total_Growth"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    - df["Percentage of Scheduled Caste Population _2001_Total"]
)

df["Rural_Urban_Gap_2011"] = (
    df["Percentage of Scheduled Caste Population _2011_Rural"]
    - df["Percentage of Scheduled Caste Population _2011_Urban"]
)

df["Estimated_2021_Total_SC_Percentage"] = (
    df["Percentage of Scheduled Caste Population _2011_Total"]
    + df["Total_Growth"]
)

feature_cols = [
    "Percentage of Scheduled Caste Population _2001_Rural",
    "Percentage of Scheduled Caste Population _2001_Urban",
    "Percentage of Scheduled Caste Population _2001_Total",
    "Percentage of Scheduled Caste Population _2011_Rural",
    "Percentage of Scheduled Caste Population _2011_Urban",
    "Percentage of Scheduled Caste Population _2011_Total",
    "Rural_Growth",
    "Urban_Growth",
    "Total_Growth",
    "Rural_Urban_Gap_2011",
]

target_col = "Estimated_2021_Total_SC_Percentage"

X = df[feature_cols]
y = df[target_col]

X_train, X_test, y_train, y_test, district_train, district_test = train_test_split(
    X,
    y,
    df[district_col],
    test_size=0.2,
    random_state=42
)

scaler = StandardScaler()
X_train_scaled_full = scaler.fit_transform(X_train)
X_test_scaled_full = scaler.transform(X_test)

scaler_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")

with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)

# =========================
# HSA FEATURE SELECTION
# Harmony Search Algorithm
# =========================

def fitness_function(mask, X_train_data, X_test_data, y_train_data, y_test_data):
    if np.sum(mask) == 0:
        return -9999

    selected_train = X_train_data[:, mask == 1]
    selected_test = X_test_data[:, mask == 1]

    model = RandomForestRegressor(
        n_estimators=100,
        random_state=42
    )

    model.fit(selected_train, y_train_data)
    preds = model.predict(selected_test)

    r2 = r2_score(y_test_data, preds)
    penalty = 0.01 * (np.sum(mask) / len(mask))

    return r2 - penalty


def hsa_feature_selection(
    X_train_data,
    X_test_data,
    y_train_data,
    y_test_data,
    num_features,
    harmony_memory_size=25,
    iterations=30,
    hmcr=0.9,
    par=0.3,
    bandwidth=1
):
    harmony_memory = np.random.randint(
        0,
        2,
        size=(harmony_memory_size, num_features)
    )

    for harmony in harmony_memory:
        if np.sum(harmony) == 0:
            harmony[np.random.randint(0, num_features)] = 1

    fitness_scores = np.array([
        fitness_function(
            harmony,
            X_train_data,
            X_test_data,
            y_train_data,
            y_test_data
        )
        for harmony in harmony_memory
    ])

    best_index = np.argmax(fitness_scores)
    best_harmony = harmony_memory[best_index].copy()
    best_fitness = fitness_scores[best_index]

    fitness_history = []

    for iteration in range(iterations):
        new_harmony = np.zeros(num_features, dtype=int)

        for feature_index in range(num_features):
            if np.random.rand() < hmcr:
                selected_harmony_index = np.random.randint(0, harmony_memory_size)
                new_harmony[feature_index] = harmony_memory[
                    selected_harmony_index,
                    feature_index
                ]

                if np.random.rand() < par:
                    new_harmony[feature_index] = 1 - new_harmony[feature_index]
            else:
                new_harmony[feature_index] = np.random.randint(0, 2)

        if np.sum(new_harmony) == 0:
            new_harmony[np.random.randint(0, num_features)] = 1

        new_fitness = fitness_function(
            new_harmony,
            X_train_data,
            X_test_data,
            y_train_data,
            y_test_data
        )

        worst_index = np.argmin(fitness_scores)

        if new_fitness > fitness_scores[worst_index]:
            harmony_memory[worst_index] = new_harmony
            fitness_scores[worst_index] = new_fitness

        current_best_index = np.argmax(fitness_scores)

        if fitness_scores[current_best_index] > best_fitness:
            best_fitness = fitness_scores[current_best_index]
            best_harmony = harmony_memory[current_best_index].copy()

        fitness_history.append(best_fitness)

        print(
            f"Iteration {iteration + 1}/{iterations} | "
            f"Best HSA Fitness: {best_fitness:.4f}"
        )

    return best_harmony, best_fitness, fitness_history


selected_mask, best_hsa_fitness, hsa_history = hsa_feature_selection(
    X_train_scaled_full,
    X_test_scaled_full,
    y_train,
    y_test,
    num_features=X_train_scaled_full.shape[1]
)

selected_features = [
    feature for feature, selected in zip(feature_cols, selected_mask)
    if selected == 1
]

X_train_scaled = X_train_scaled_full[:, selected_mask == 1]
X_test_scaled = X_test_scaled_full[:, selected_mask == 1]

models = {
    "HSA_RandomForest": RandomForestRegressor(
        n_estimators=200,
        random_state=42
    ),
    "HSA_GradientBoosting": GradientBoostingRegressor(
        n_estimators=200,
        learning_rate=0.05,
        random_state=42
    )
}

results = []
all_predictions = {}

best_model = None
best_model_name = None
best_r2 = -999

for name, model in models.items():
    model.fit(X_train_scaled, y_train)

    preds = model.predict(X_test_scaled)
    all_predictions[name] = preds

    mae = mean_absolute_error(y_test, preds)
    mse = mean_squared_error(y_test, preds)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, preds)

    results.append({
        "Model": name,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2_Score": r2,
        "Accuracy_Percentage": r2 * 100
    })

    model_path = os.path.join(
        OUTPUT_DIR,
        PREFIX + name.lower() + "_model.pkl"
    )

    with open(model_path, "wb") as f:
        pickle.dump(model, f)

    if r2 > best_r2:
        best_r2 = r2
        best_model = model
        best_model_name = name

dl_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dense(1)
])

dl_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = dl_model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,
    epochs=300,
    batch_size=8,
    callbacks=[early_stop],
    verbose=1
)

dl_preds = dl_model.predict(X_test_scaled).flatten()

all_predictions["HSA_DeepNeuralNetwork"] = dl_preds

dl_mae = mean_absolute_error(y_test, dl_preds)
dl_mse = mean_squared_error(y_test, dl_preds)
dl_rmse = np.sqrt(dl_mse)
dl_r2 = r2_score(y_test, dl_preds)

results.append({
    "Model": "HSA_DeepNeuralNetwork",
    "MAE": dl_mae,
    "MSE": dl_mse,
    "RMSE": dl_rmse,
    "R2_Score": dl_r2,
    "Accuracy_Percentage": dl_r2 * 100
})

h5_path = os.path.join(OUTPUT_DIR, PREFIX + "deep_learning_model.h5")
dl_model.save(h5_path)

if dl_r2 > best_r2:
    best_r2 = dl_r2
    best_model_name = "HSA_DeepNeuralNetwork"

best_model_path = os.path.join(OUTPUT_DIR, PREFIX + "best_model.pkl")

if best_model is not None:
    with open(best_model_path, "wb") as f:
        pickle.dump(best_model, f)

feature_selection_data = {
    "algorithm": "Harmony Search Algorithm",
    "selected_mask": selected_mask.tolist(),
    "selected_features": selected_features,
    "best_hsa_fitness": float(best_hsa_fitness),
    "hsa_history": [float(x) for x in hsa_history]
}

feature_selection_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "feature_selection.json"
)

with open(feature_selection_path, "w") as f:
    json.dump(feature_selection_data, f, indent=4)

results_df = pd.DataFrame(results)

results_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "results.csv")
results_df.to_csv(results_csv_path, index=False)

prediction_df = pd.DataFrame({
    "District": district_test.values,
    "Actual_2021_Estimated_SC_Percentage": y_test.values
})

for model_name, preds in all_predictions.items():
    prediction_df[f"{model_name}_Prediction"] = preds

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "predictions.csv")
prediction_df.to_csv(prediction_csv_path, index=False)

json_data = {
    "project_name": "Scheduled Caste Population Growth & Demographic Forecasting System",
    "author": "Sagnik Patra",
    "algorithm": "Harmony Search Algorithm Feature Selection",
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": target_col,
    "all_features": feature_cols,
    "selected_features": selected_features,
    "best_model": best_model_name,
    "best_r2_score": float(best_r2),
    "best_hsa_fitness": float(best_hsa_fitness),
    "model_results": results_df.to_dict(orient="records")
}

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

with open(json_path, "w") as f:
    json.dump(json_data, f, indent=4)

yaml_config = {
    "project": {
        "name": "Scheduled Caste Population Growth & Demographic Forecasting System",
        "author": "Sagnik Patra",
        "prefix": PREFIX,
        "algorithm": "HSA"
    },
    "paths": {
        "dataset_path": DATASET_PATH,
        "output_directory": OUTPUT_DIR,
        "h5_model": h5_path,
        "best_model_pkl": best_model_path,
        "scaler_pkl": scaler_path,
        "results_csv": results_csv_path,
        "predictions_csv": prediction_csv_path,
        "json_results": json_path,
        "feature_selection_json": feature_selection_path
    },
    "training": {
        "test_size": 0.2,
        "random_state": 42,
        "target_column": target_col,
        "all_features": feature_cols,
        "selected_features": selected_features
    },
    "hsa_parameters": {
        "harmony_memory_size": 25,
        "iterations": 30,
        "hmcr": 0.9,
        "par": 0.3,
        "bandwidth": 1
    },
    "best_model": best_model_name
}

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

with open(yaml_path, "w") as f:
    yaml.dump(yaml_config, f, default_flow_style=False)

plt.figure(figsize=(10, 6))
plt.bar(results_df["Model"], results_df["Accuracy_Percentage"])
plt.xlabel("Models")
plt.ylabel("Accuracy Percentage")
plt.title("HSA Model Accuracy Graph")
plt.xticks(rotation=30)
plt.tight_layout()
accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")
plt.savefig(accuracy_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["MAE"], marker="o", label="MAE")
plt.plot(results_df["Model"], results_df["RMSE"], marker="o", label="RMSE")
plt.xlabel("Models")
plt.ylabel("Error Value")
plt.title("HSA Comparison Graph")
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()
comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")
plt.savefig(comparison_graph_path)
plt.show()

corr = df[selected_features + [target_col]].corr()

plt.figure(figsize=(12, 8))
plt.imshow(corr, interpolation="nearest")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("HSA Selected Feature Heatmap")
plt.tight_layout()
heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")
plt.savefig(heatmap_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(results_df["Model"], results_df["R2_Score"], marker="o")
plt.xlabel("Models")
plt.ylabel("R2 Score")
plt.title("HSA Result Graph")
plt.xticks(rotation=30)
plt.tight_layout()
result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")
plt.savefig(result_graph_path)
plt.show()

best_prediction_col = f"{best_model_name}_Prediction"

plt.figure(figsize=(12, 6))
plt.plot(
    prediction_df["District"],
    prediction_df["Actual_2021_Estimated_SC_Percentage"],
    marker="o",
    label="Actual"
)

plt.plot(
    prediction_df["District"],
    prediction_df[best_prediction_col],
    marker="o",
    label="Predicted"
)

plt.xlabel("District")
plt.ylabel("SC Population Percentage")
plt.title(f"HSA Prediction Graph - {best_model_name}")
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")
plt.savefig(prediction_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(hsa_history, marker="o")
plt.xlabel("Iteration")
plt.ylabel("Best Fitness")
plt.title("HSA Optimization Progress Graph")
plt.tight_layout()
optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")
plt.savefig(optimization_graph_path)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("HSA Deep Learning Loss Graph")
plt.legend()
plt.tight_layout()
dl_loss_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "dl_loss_graph.png")
plt.savefig(dl_loss_graph_path)
plt.show()

print("\nHSA execution completed successfully!")

print("\nSelected Features:")
for feature in selected_features:
    print("-", feature)

print("\nSaved CSV Files:")
print(results_csv_path)
print(prediction_csv_path)

print("\nSaved Model Files:")
print(h5_path)
print(best_model_path)
print(scaler_path)

print("\nSaved Config Files:")
print(json_path)
print(yaml_path)
print(feature_selection_path)

print("\nSaved Graphs:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(dl_loss_graph_path)

print("\nModel Results:")
print(results_df)
# Out:
# Iteration 1/30 | Best HSA Fitness: 0.9792
# Iteration 2/30 | Best HSA Fitness: 0.9792
# Iteration 3/30 | Best HSA Fitness: 0.9792
# Iteration 4/30 | Best HSA Fitness: 0.9792
# Iteration 5/30 | Best HSA Fitness: 0.9792
# Iteration 6/30 | Best HSA Fitness: 0.9792
# Iteration 7/30 | Best HSA Fitness: 0.9792
# Iteration 8/30 | Best HSA Fitness: 0.9792
# Iteration 9/30 | Best HSA Fitness: 0.9832
# Iteration 10/30 | Best HSA Fitness: 0.9832
# Iteration 11/30 | Best HSA Fitness: 0.9832
# Iteration 12/30 | Best HSA Fitness: 0.9832
# Iteration 13/30 | Best HSA Fitness: 0.9832
# Iteration 14/30 | Best HSA Fitness: 0.9832
# Iteration 15/30 | Best HSA Fitness: 0.9832
# Iteration 16/30 | Best HSA Fitness: 0.9832
# Iteration 17/30 | Best HSA Fitness: 0.9832
# Epoch 28/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6522 - mae: 1.6862 - val_loss: 0.5895 - val_mae: 0.6679
# Epoch 29/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4139 - mae: 1.8229 - val_loss: 0.4579 - val_mae: 0.4989
# Epoch 30/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.3222 - mae: 1.6351 - val_loss: 0.4568 - val_mae: 0.5111
# Epoch 31/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9823 - mae: 1.7126 - val_loss: 0.3350 - val_mae: 0.5037
# Epoch 32/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0051 - mae: 1.3401 - val_loss: 0.4268 - val_mae: 0.5611
# Epoch 33/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7656 - mae: 1.5203 - val_loss: 0.4222 - val_mae: 0.5351
# Epoch 34/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4138 - mae: 1.5413 - val_loss: 0.2736 - val_mae: 0.4285
# Epoch 35/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0721 - mae: 1.5969 - val_loss: 0.3393 - val_mae: 0.3860
# Epoch 36/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8744 - mae: 1.3806 - val_loss: 0.3635 - val_mae: 0.4038
# Epoch 37/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2645 - mae: 1.6417 - val_loss: 0.4164 - val_mae: 0.5293
# Epoch 38/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4550 - mae: 1.3507 - val_loss: 0.3784 - val_mae: 0.4794
# Epoch 39/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3495 - mae: 1.5974 - val_loss: 0.3315 - val_mae: 0.4332
# Epoch 40/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5202 - mae: 1.4496 - val_loss: 0.5262 - val_mae: 0.5150
# Epoch 41/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0467 - mae: 1.5125 - val_loss: 0.4902 - val_mae: 0.3865
# Epoch 42/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1235 - mae: 1.5062 - val_loss: 1.1831 - val_mae: 0.9220
# Epoch 43/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5165 - mae: 1.3944 - val_loss: 0.3223 - val_mae: 0.3210
# Epoch 44/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9398 - mae: 1.4796 - val_loss: 1.0173 - val_mae: 0.7666
# Epoch 45/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7082 - mae: 1.6220 - val_loss: 0.7229 - val_mae: 0.4538
# Epoch 46/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7930 - mae: 1.5120 - val_loss: 0.8293 - val_mae: 0.4144
# Epoch 47/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8321 - mae: 1.4174 - val_loss: 0.9572 - val_mae: 0.6807
# Epoch 48/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2059 - mae: 1.3262 - val_loss: 0.4569 - val_mae: 0.5128
# Epoch 49/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0298 - mae: 1.3957 - val_loss: 0.3871 - val_mae: 0.3704
# Epoch 50/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8926 - mae: 1.3779 - val_loss: 0.4811 - val_mae: 0.4047
# Epoch 51/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1699 - mae: 1.5669 - val_loss: 0.4544 - val_mae: 0.3305
# Epoch 52/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5781 - mae: 1.4120 - val_loss: 0.7263 - val_mae: 0.6358
# Epoch 53/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2197 - mae: 1.2722 - val_loss: 0.6939 - val_mae: 0.6295
# Epoch 54/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6232 - mae: 1.3660 - val_loss: 0.3141 - val_mae: 0.4278
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# HSA execution completed successfully!
#
# Selected Features:
# - Percentage of Scheduled Caste Population _2001_Total
# - Percentage of Scheduled Caste Population _2011_Total
# - Total_Growth
#
# Saved CSV Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_results.csv
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_predictions.csv
#
# Saved Model Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_deep_learning_model.h5
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_best_model.pkl
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_scaler.pkl
#
# Saved Config Files:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_results.json
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_config.yaml
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_feature_selection.json
#
# Saved Graphs:
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_heatmap.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_result_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Scheduled Caste Population Growth & Demographic Forecasting System\hsa_dl_loss_graph.png
#
# Model Results:
#                    Model       MAE       MSE      RMSE  R2_Score  \
# 0       HSA_RandomForest  0.556901  1.012811  1.006385  0.986019
# 1   HSA_GradientBoosting  0.639516  1.313975  1.146287  0.981861
# 2  HSA_DeepNeuralNetwork  0.519917  0.599013  0.773959  0.991731
#
#    Accuracy_Percentage
# 0            98.601880
# 1            98.186143
# 2            99.173101
